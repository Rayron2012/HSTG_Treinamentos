# %% [markdown]
# # for + if
#
# ### Estrutura:

# %% [raw]
# for item in lista:
#     if condicao:
#         faça alguma coisa
#     else:
#         outra coisa

# %% [markdown]
# Digamos que a gente esteja analisando a meta de vendas de vários funcionários de uma empresa. A meta de vendas é de 1000 reais em 1 dia.
#
# Temos uma lista com as vendas de todos os funcionários e quero calcular qual o % de pessoas que bateram a meta.

# %%
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
meta = 1000
n_meta = []
qtd_meta = 0

for valor in vendas:
    if valor >= meta:
        qtd_meta += 1
        n_meta.append(valor)
        

    else:
        pass     
print(n_meta, qtd_meta, len(n_meta)) 
print("A quantidade de pessoas na lista é de {} e dessa quantidade, {} bateram a meta, representando {:.0f}%".format(len(vendas), qtd_meta, (qtd_meta/len(vendas))*100))
# Out:
# [1200, 1500, 1900, 2750, 1100, 1111] 6 6
# A quantidade de pessoas na lista é de 23 e dessa quantidade, 6 bateram a meta, representando 26%
