# %% [markdown]
# # Exercícios
#
# ## 1. Criando um Registro de Hóspedes
#
# Digamos que você está criando o sistema para registrar a chegada de hóspedes em um hotel. No hotel, os hóspedes podem ter quartos com 1, 2, 3 e 4 pessoas. Seu sistema deve conseguir:
#
# 1. Identificar quantas pessoas o hóspede que acabou de chegar vai ter no quarto (perguntando por meio de input)
# 2. De acordo com a quantidade de pessoas do hóspede, ele deve fazer um for para perguntar o cpf e o nome de cada pessoa, a fim de registrá-la no quarto (2 inputs para cada pessoa, 1 para o cpf e outro para o nome)
# 3. O seu programa então deve gerar uma lista com todas as pessoas que ficarão no quarto em que cada item dessa lista é o nome da pessoa e o cpf da pessoa, assim:

# %% [raw]
# quarto = [
#     ['João', 'cpf:00000000000'],
#     ['Julia', 'cpf:11111111111'],
#     ['Marcus', 'cpf:22222222222'],
#     ['Maria', 'cpf:33333333333'],
# ]

# %% [markdown]
# - Para simplificar, não vamos nos preocupar com possibilidades de "tentar colocar mais de 1 hóspede, digitar o cpf errado, etc. Nosso objetivo é treinar a criação de uma rotina de cadastro

# %%
#seu código aqui

qtd_pessoas= int(input("Quantas pessoas terão no quarto? "))

quarto = []

for i in range(qtd_pessoas):
    nome = input(f"Digite o nome da {i+1}ª pessoa: ")
    cpf = input(f"Digite o CPF da {i+1}ª pessoa: ")
    hospede = [nome, cpf]
    quarto.append(hospede)

print(quarto)
# Out:
# [['Ray', '12312312312'], ['Leia', '32132132132']]

# %% [markdown]
# ## 2. Análise de Vendas
#
# Nesse exercício vamos fazer uma "análise simples" de atingimento de Meta.
#
# Temos uma lista com os vendedores e os valores de vendas e queremos identificar (printar) quais os vendedores que bateram a meta e qual foi o valor que eles venderam.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
#seu código aqui

for venda in vendas:
    if venda[1] >= meta:
        print(f"Vendedor: {venda[0]}, vendas: {venda[1]}")
# Out:
# Vendedor: João, vendas: 15000
# Vendedor: Julia, vendas: 27000
# Vendedor: Ana, vendas: 10300

# %% [markdown]
# ## 3. Comparação com Ano Anterior
#
# Digamos que você está analisando as vendas de produtos de um ecommerce e quer identificar quais produtos tiveram no ano de 2020 mais vendas do que no ano de 2019, para reportar isso para a diretoria.
#
# Sua resposta pode ser um print de cada produto, qual foi a venda de 2019, a venda de 2020 e o % de crescimento de 2020 para 2019.
#
# Lembrando, para calcular o % de crescimento de um produto de um ano para o outro, podemos fazer: (vendas_produto2020/vendas_produto2019 - 1)
#
# Dica: lembre do enumerate, ele pode facilitar seu "for"

# %%
produtos = ['iphone', 'galaxy', 'ipad', 'tv', 'máquina de café', 'kindle', 'geladeira', 'adega', 'notebook dell', 'notebook hp', 'notebook asus', 'microsoft surface', 'webcam', 'caixa de som', 'microfone', 'câmera canon']
vendas2019 = [558147,712350,573823,405252,718654,531580,973139,892292,422760,154753,887061,438508,237467,489705,328311,591120]
vendas2020 = [951642,244295,26964,787604,867660,78830,710331,646016,694913,539704,324831,667179,295633,725316,644622,994303]
#seu código aqui


for i, produto in enumerate(produtos):
    if vendas2020[i] > vendas2019[i]:
        print(f"O produto {produto} teve vendeu mais em 2020: {vendas2020[i]:,}. Em relacáo ao mesmo perido de 2019: {vendas2019[i]:,}. Havendo um crescimento de {vendas2020[i] / vendas2019[i] - 1:.0%}%\n")
# Out:
# O produto iphone teve vendeu mais em 2020: 951,642. Em relacáo ao mesmo perido de 2019: 558,147. Havendo um crescimento de 71%%
#
# O produto tv teve vendeu mais em 2020: 787,604. Em relacáo ao mesmo perido de 2019: 405,252. Havendo um crescimento de 94%%
#
# O produto máquina de café teve vendeu mais em 2020: 867,660. Em relacáo ao mesmo perido de 2019: 718,654. Havendo um crescimento de 21%%
#
# O produto notebook dell teve vendeu mais em 2020: 694,913. Em relacáo ao mesmo perido de 2019: 422,760. Havendo um crescimento de 64%%
#
# O produto notebook hp teve vendeu mais em 2020: 539,704. Em relacáo ao mesmo perido de 2019: 154,753. Havendo um crescimento de 249%%
#
# O produto microsoft surface teve vendeu mais em 2020: 667,179. Em relacáo ao mesmo perido de 2019: 438,508. Havendo um crescimento de 52%%
#
# O produto webcam teve vendeu mais em 2020: 295,633. Em relacáo ao mesmo perido de 2019: 237,467. Havendo um crescimento de 24%%
#
# O produto caixa de som teve vendeu mais em 2020: 725,316. Em relacáo ao mesmo perido de 2019: 489,705. Havendo um crescimento de 48%%
#
# O produto microfone teve vendeu mais em 2020: 644,622. Em relacáo ao mesmo perido de 2019: 328,311. Havendo um crescimento de 96%%
#
# O produto câmera canon teve vendeu mais em 2020: 994,303. Em relacáo ao mesmo perido de 2019: 591,120. Havendo um crescimento de 68%%
