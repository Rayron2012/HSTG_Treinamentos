# %% [markdown]
# ### Facilitando com o metodo fortmat

# %% [markdown]
# #### Temos que semprwe prestar a atenção, na ordem das variaveisque declaramos para náo colocar valores errados nas declarações

# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo


print('O faturamento das sua vendas é de: {}. Ocusto foi de {}. Sobrando um lucro de {}'.format(faturamento, custo, lucro))
# Out:
# O faturamento das sua vendas é de: 2000. Ocusto foi de 500. Sobrando um lucro de 1500
