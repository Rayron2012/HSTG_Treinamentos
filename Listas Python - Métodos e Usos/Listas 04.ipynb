# %% [markdown]
# # Adicionar e Remover itens de uma lista
#
# Adicionar:<br>
# lista.append(item)
#
# Remover:<br>
# item_removido = lista.pop(indice)<br>
# lista.remove(item)
#
# Digamos que você está construindo o controle de produtos da Apple.<br>
# E a Apple lançou o IPhone 11 e irá tirar dos seus estoques o IPhone X

# %%
produtos = ['apple tv', 'mac', 'iphone 16', 'IPad', 'apple watch', 'mac book', 'airpods']
print(produtos)

# Trocar o Iphone da lista:
# produtos[2] = "iphone 17"
# print(produtos)

# Adicionar iphone 17
produtos.append("iphone 17")
print(produtos)


# Remover Iphone 16, existem duas formar de fazer isso
# produtos.remove("iphone 16")
# rm = produtos.pop(2)
# print(produtos)
# print(f"Produto {rm}, removido")
# Out:
# ['apple tv', 'mac', 'iphone 16', 'IPad', 'apple watch', 'mac book', 'airpods']
# ['apple tv', 'mac', 'iphone 16', 'IPad', 'apple watch', 'mac book', 'airpods', 'iphone 17']

# %% [markdown]
# ## Existem 2 formas de tratar o erro:
#
# 1. Criar um if para evitar que ele aconteça
#
# 2. Esperar que ele possa acontecer e tratar caso o erro aconteça com:

# %% [raw]
# try:
#     tentar fazer
# except:
#     caso dê errado

# %%
rm2 = "iphone 16"
try:
    produtos.remove(rm2)
    print(f"O produto {rm2} foi removido")
except:
    print(f"O produto {rm2} náo esta na lista de produtos")
# Out:
# O produto iphone 16 foi removido
