# %% [markdown]
# ## Tempo até o próximo ano
#
# Crie um script Python que calcula quantos dias, horas, minutos e segundos faltam até o próximo Ano Novo.

# %% [markdown]
# Lembrar da tupla de struct_time: https://docs.python.org/3/library/time.html#time.struct_time

# %%
# lembrando

segundos_por_minuto = 60
segundos_por_hora = 60 * 60
segundos_por_dia = 24 * 60 * 60

print(f"Segundos em um minuto: {segundos_por_minuto} s")
print(f"Segundos em uma hora: {segundos_por_hora} s")
print(f"Segundos em um dia: {segundos_por_dia} s")
# Out:
# Segundos em um minuto: 60 s
# Segundos em uma hora: 3600 s
# Segundos em um dia: 86400 s

# %% [markdown]
# Lembrando de divisão:
#
# ![divisao](https://escolaeducacao.com.br/wp-content/uploads/2020/01/algoritmo-divisao.png)

# %%
import time

tempo_atual = time.localtime()
tempo_ano_novo = (tempo_atual.tm_year + 1, 1, 1, 0, 0, 0, 0, 0, 0)

tempo_ano_novo_em_segundos = time.mktime(tempo_ano_novo)
tempo_atual_em_segundos = time.mktime(tempo_atual)

diferenca_em_segundos = int(tempo_ano_novo_em_segundos - tempo_atual_em_segundos)

dias_restantes = diferenca_em_segundos // segundos_por_dia
horas_restantes = (diferenca_em_segundos % segundos_por_dia) // segundos_por_hora
minutos_restantes = (diferenca_em_segundos % segundos_por_hora) // segundos_por_minuto
segundos_restantes = diferenca_em_segundos % segundos_por_minuto 

for i in range(10): 
    tempo_atual = time.localtime()
    tempo_ano_novo = (tempo_atual.tm_year + 1, 1, 1, 0, 0, 0, 0, 0, 0)

    tempo_ano_novo_em_segundos = time.mktime(tempo_ano_novo)
    tempo_atual_em_segundos = time.mktime(tempo_atual)

    diferenca_em_segundos = int(tempo_ano_novo_em_segundos - tempo_atual_em_segundos)

    dias_restantes = diferenca_em_segundos // segundos_por_dia
    horas_restantes = (diferenca_em_segundos % segundos_por_dia) // segundos_por_hora
    minutos_restantes = (diferenca_em_segundos % segundos_por_hora) // segundos_por_minuto
    segundos_restantes = diferenca_em_segundos % segundos_por_minuto 
    print(f"Faltam {dias_restantes} dias, {horas_restantes} horas, {minutos_restantes} minutos e {segundos_restantes} segundos para o Ano Novo!", end='\r')
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 tempo_atual_em_segundos = time.mktime(tempo_atual)
#       9 diferenca_em_segundos = int(tempo_ano_novo_em_segundos - tempo_atual_em_segundos)
# ---> 11 dias_restantes = diferenca_em_segundos // segundos_por_dia
#      12 horas_restantes = (diferenca_em_segundos % segundos_por_dia) // segundos_por_hora
#      13 minutos_restantes = (diferenca_em_segundos % segundos_por_hora) // segundos_por_minuto
#
# NameError: name 'segundos_por_dia' is not defined
