# %% [markdown]
# # Range
#
# ### Estrutura:
#
# - range(tamanho)
#
# ou
#
# - range(inicio, fim)
#
# ou
#
# - range(inicio, fim, passo)

# %%
#uso mais comum no for:
produtos = ['arroz', 'feijao', 'macarrao', 'atum', 'azeite']
estoque = [50, 100, 20, 5, 80]

for i, produto in enumerate(produtos):
    print('No indice {} temos o produto {} custando {}'.format(i, produto, estoque[i]))
# Out:
# No indice 0 temos o produto arroz custando 50
# No indice 1 temos o produto feijao custando 100
# No indice 2 temos o produto macarrao custando 20
# No indice 3 temos o produto atum custando 5
# No indice 4 temos o produto azeite custando 80

# %%
#range com inicio e fim
print(range(1, 10))

for i in range(1, 1000, 100):
    print(i)
#vamos olhar no for para entender
# Out:
# range(1, 10)
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901

# %% [markdown]
# - Exemplo: Modelo Jack Welch da G&E
#
#     1. Classe A: 10% melhor
#     2. Classe B: 80% mantém/busca melhorar
#     3. Classe C: 10% pior
#
# Quem são os funcionários classe B?

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo']
vendas = [2750, 1900, 1500, 1200, 1111, 1100, 999, 900, 880, 870, 800, 800, 450, 400, 300, 300, 120, 90, 80, 70]

for i in range(2, 18):
    print('O funcionário {} vendeu {}'.format(funcionarios[i], vendas[i]))
# Out:
# O funcionário Antônio vendeu 1500
# O funcionário João vendeu 1200
# O funcionário Francisco vendeu 1111
# O funcionário Ana vendeu 1100
# O funcionário Luiz vendeu 999
# O funcionário Paulo vendeu 900
# O funcionário Carlos vendeu 880
# O funcionário Manoel vendeu 870
# O funcionário Pedro vendeu 800
# O funcionário Francisca vendeu 800
# O funcionário Marcos vendeu 450
# O funcionário Raimundo vendeu 400
# O funcionário Sebastião vendeu 300
# O funcionário Antônia vendeu 300
# O funcionário Marcelo vendeu 120
# O funcionário Jorge vendeu 90

# %%
#range com passo
print(range(0, 1000, 10))

for i in range(0, 1000, 10):
    print(i)
