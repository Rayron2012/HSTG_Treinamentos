# %% [markdown]
# # Treinamento Python — 200 exercícios progressivos
#
# Gerado em: 2026-02-02 15:59
#
# **Como usar**
# - Faça na ordem.
# - Não copie/cole solução: escreva do zero.
# - Sempre que travar: rascunhe o algoritmo em português antes do código.
# - Depois de resolver, **refatore** (melhore nomes, quebre em funções, evite repetição).
#
# ---

# %% [markdown]
# ## 0–100: fundamentos e base (fácil → sólido)
#
# 1. Leia um nome e imprima: `Olá, <nome>!`
# 2. Leia dois números e imprima soma, subtração, multiplicação e divisão (com 2 casas).
# 3. Converta Celsius → Fahrenheit.
# 4. Converta minutos → horas e minutos (ex: 135 → 2h15).
# 5. Leia um número e diga se é par ou ímpar.
# 6. Leia um número e diga se é positivo, negativo ou zero.
# 7. Leia 3 números e imprima o maior.
# 8. Leia 3 números e imprima o menor.
# 9. Leia 3 números e imprima em ordem crescente.
# 10. Leia um ano e diga se é bissexto.
# 11. Leia uma string e diga quantos caracteres ela tem.
# 12. Leia uma string e imprima ela ao contrário.
# 13. Verifique se uma palavra é palíndromo.
# 14. Conte quantas vogais existem numa frase.
# 15. Conte quantas consoantes existem numa frase.
# 16. Conte quantos espaços existem numa frase.
# 17. Transforme uma frase em “título” (iniciais maiúsculas).
# 18. Substitua todas as ocorrências de uma palavra por outra.
# 19. Remova pontuação simples de uma frase (`.,!?`).
# 20. Verifique se um e-mail tem `@` e pelo menos um `.` depois do `@`.
# 21. Leia um inteiro N e imprima de 1 a N.
# 22. Imprima de N até 1.
# 23. Some de 1 a N.
# 24. Some apenas os pares de 1 a N.
# 25. Calcule fatorial de N.
# 26. Imprima a tabuada de N (1 a 10).
# 27. Faça um contador regressivo com mensagem “GO!” no final.
# 28. Some números até o usuário digitar 0 (sentinela).
# 29. Valide entrada: peça um número entre 1 e 10 até ser válido.
# 30. Jogo: adivinhe o número fixo (ex: 7) com tentativas.
# 31. Leia 5 notas e calcule média.
# 32. Leia notas até o usuário digitar “fim” e calcule média.
# 33. Conte quantas notas estão acima da média.
# 34. Leia 10 números e conte quantos são pares.
# 35. Leia 10 números e ache o maior e o menor.
# 36. Leia números e pare quando o usuário repetir um número (detecta duplicata).
# 37. Gere uma lista de 20 números e some tudo (sem random, pode ser input).
# 38. Faça a soma acumulada (prefix sum) de uma lista.
# 39. Encontre o segundo maior número numa lista.
# 40. Remova duplicatas mantendo a ordem.
# 41. Dada uma lista, crie outra só com números > 10.
# 42. Dada uma lista, crie outra só com números pares.
# 43. Dada uma lista de nomes, filtre os que começam com “A”.
# 44. Dada uma lista de palavras, filtre as que têm mais de 5 letras.
# 45. Dada uma lista de strings numéricas, converta pra int.
# 46. Faça um “join” manual: junte palavras com `-` sem usar `join`.
# 47. Separe uma frase em palavras sem usar `split`.
# 48. Encontre a palavra mais longa de uma frase.
# 49. Conte frequência de letras numa palavra (sem dict pronto ainda: pode lista).
# 50. Simule um menu simples (1-cadastrar, 2-listar, 0-sair).
# 51. Crie um dicionário com 5 produtos e preços.
# 52. Some o total de um “carrinho” (dict produto→preço).
# 53. Aplique 10% de desconto se total > 100.
# 54. Conte quantas chaves existem num dict.
# 55. Inverta um dict simples (valor vira chave) quando não houver conflito.
# 56. Crie um dict de frequência de palavras numa frase.
# 57. Ache a palavra mais frequente.
# 58. Atualize estoque (dict produto→qtd) após uma compra.
# 59. Liste produtos com estoque abaixo de 5.
# 60. Faça um “cadastro” de usuários (nome→idade) e liste maiores de 18.
# 61. Verifique se um número está presente numa lista.
# 62. Verifique se uma palavra está presente numa lista.
# 63. Remova um item de uma lista pelo valor (se existir).
# 64. Remova um item de uma lista pelo índice (validando).
# 65. Ordene uma lista sem usar `sorted` (bubble sort simples).
# 66. Conte quantas vezes um número aparece numa lista (sem `.count()`).
# 67. Compare duas listas e diga quais itens existem em ambas.
# 68. Crie a união de duas listas sem duplicar.
# 69. Crie a interseção de duas listas.
# 70. Crie a diferença (itens da A que não estão na B).
# 71. Converta um número decimal pra binário (sem `bin`).
# 72. Converta um binário (string) pra decimal.
# 73. Verifique se um número é primo.
# 74. Liste primos até N.
# 75. Gere sequência de Fibonacci até N termos.
# 76. Somatório de Fibonacci (soma dos termos).
# 77. Crie uma matriz 3x3 e some diagonal principal.
# 78. Some todos os elementos de uma matriz.
# 79. Encontre o maior elemento de uma matriz.
# 80. Conte zeros numa matriz.
# 81. Faça um mini “caixa eletrônico” com notas 50/20/10/5/2.
# 82. Calcule troco mínimo com moedas (greedy simples).
# 83. Dado um horário HH:MM, some X minutos.
# 84. Dado dois horários, calcule diferença em minutos.
# 85. Valide CPF (não precisa regra completa; só formato `xxx.xxx.xxx-xx`).
# 86. Valide senha: 8+ chars, 1 número, 1 letra.
# 87. Conte quantas senhas válidas existem numa lista.
# 88. Dado texto, normalize: lower, sem acento (trocas básicas ok).
# 89. Faça um “censor”: substitua palavras proibidas por `***`.
# 90. Faça um placar de jogo: some pontos por rodada.
# 91. Faça uma calculadora que aceita operador (+-*/).
# 92. Faça uma calculadora que aceita expressão “a op b” (string) e calcula.
# 93. Faça um gerador de username: nome+sobrenome+2 últimos dígitos do ano.
# 94. Faça uma lista de tarefas: add/list/remove.
# 95. Faça um cronômetro simples (simulado via loop).
# 96. Converta lista de ints em string “1,2,3” sem `join`.
# 97. Leia 10 palavras e agrupe por tamanho (dict tamanho→lista).
# 98. Leia nomes e agrupe por primeira letra (dict letra→lista).
# 99. Leia números e separe em pares e ímpares (duas listas).
# 100. Pegue uma frase e retorne as 3 palavras mais comuns (com desempate alfabético).

# %% [markdown]
# ## 101–200: intermediário (funções, comprehensions, iteráveis, arquivos)
#
# 101. Crie `eh_par(n)` e use pra filtrar uma lista.
# 102. Crie `eh_primo(n)` e use pra listar primos até N.
# 103. Crie `media(lista)` e trate lista vazia.
# 104. Crie `maior(lista)` sem usar `max`.
# 105. Crie `menor(lista)` sem usar `min`.
# 106. Crie `normaliza_texto(s)` (lower + remove pontuação básica).
# 107. Crie `conta_palavras(s)` que retorna dict palavra→freq (com normalização).
# 108. Crie `top_k_frequentes(dict_freq, k)` que retorna lista de tuplas.
# 109. Crie `valida_email(s)` com regras simples.
# 110. Crie `valida_senha(s)` (regras: 8+ chars, 1 número, 1 letra).
# 111. Crie `soma_pares(lista)` usando `eh_par`.
# 112. Crie `separa_pares_impares(lista)` retornando duas listas.
# 113. Crie `remove_duplicatas(lista)` mantendo ordem.
# 114. Crie `intersecao(a,b)` sem usar set.
# 115. Crie `uniao(a,b)` sem usar set.
# 116. Crie `diferenca(a,b)` sem usar set.
# 117. Crie `conta_letras(s)` retornando dict letra→freq.
# 118. Crie `palindromo(s)` ignorando espaços e pontuação.
# 119. Crie `anagrama(a,b)` ignorando espaços.
# 120. Crie `slugify(s)` (texto de URL: lower, hífen, sem espaços repetidos).
# 121. Crie `parse_inteiro(s, default=None)` (se falhar retorna default).
# 122. Crie `safe_div(a,b)` que não explode com divisão por zero.
# 123. Crie `format_money(valor)` (R$ 1.234,56) — pode simplificar.
# 124. Crie `desconto(total, cupom)` onde cupom é dict de regras.
# 125. Crie `aplica_descontos(carrinho, regras)` (funções chamando funções).
# 126. Crie `merge_dicts(a,b)` somando valores iguais.
# 127. Crie `invert_dict(d)` mas quando houver conflito, agrupe em lista.
# 128. Crie `chunks(lista, tamanho)` que divide a lista em pedaços.
# 129. Crie `flatten(matriz)` que transforma matriz em lista.
# 130. Crie `uniq_by(lista, chave_func)` (passa função que define a chave).
# 131. Gere lista de quadrados de 1 a 20 com comprehension.
# 132. Gere lista de pares de 1 a 100 com comprehension.
# 133. Gere lista de múltiplos de 3 e 5 até 200.
# 134. Dada lista de strings numéricas, converta pra int via comprehension.
# 135. Dada lista de palavras, pegue só as que têm vogais > consoantes.
# 136. Dada lista de nomes, crie lista com nomes em “Title Case”.
# 137. Dada lista de números, crie lista de tuplas `(n, n², n³)`.
# 138. Dada frase, crie lista de palavras sem pontuação (usando sua normalização).
# 139. Dada lista de frases, gere lista com contagem de palavras por frase.
# 140. Dada lista de listas, crie lista achatada (flatten) com comprehension.
# 141. Dado dict produto→preço, gere lista de “Produto: R$xx”.
# 142. Dado dict palavra→freq, gere lista só das palavras com freq >= 3.
# 143. Crie dict comprehension: número→se é primo (True/False) de 1..50.
# 144. Crie dict comprehension: letra→ASCII (ord) para ‘a’..‘z’.
# 145. Crie set comprehension: letras únicas de uma frase normalizada.
# 146. Dada lista, gere dict `n→contador_de_divisores(n)`.
# 147. Dada lista de idades, gere dict `faixa_etaria→quantidade`.
# 148. Dada lista de produtos (tuplas), gere dict `categoria→lista_de_produtos`.
# 149. Dada lista de emails, filtre válidos e normalize (lower/strip) em 1 linha.
# 150. Dada matriz, gere lista com soma de cada linha (comprehension + sum).
# 151. Reescreva `remove_duplicatas` usando set *sem* perder ordem.
# 152. Use `enumerate` pra gerar lista `(idx, valor)` só dos valores > 0.
# 153. Use `zip` pra somar elemento a elemento duas listas (tamanhos iguais).
# 154. Use `zip` pra criar dict a partir de duas listas: chaves e valores.
# 155. Use `zip` pra transpor uma matriz (linhas viram colunas).
# 156. Use `sorted` com `key` pra ordenar palavras por tamanho e depois alfabético.
# 157. Use `sorted` com `key` pra ordenar produtos por preço.
# 158. Use `sorted` pra pegar top 5 mais frequentes do dict palavra→freq.
# 159. Dada lista de notas, use `any` pra ver se existe nota zero.
# 160. Dada lista de notas, use `all` pra ver se todas são >= 7.
# 161. “Agenda”: funções `adicionar`, `buscar`, `remover`, `listar` (dict nome→fone).
# 162. Agenda com múltiplos telefones por nome (dict nome→lista).
# 163. Agenda com validação de telefone (tamanho mínimo).
# 164. “Estoque”: CRUD simples de produtos (dict produto→{preco,qtd}).
# 165. Estoque: função `vender(produto, qtd)` com checagens.
# 166. Estoque: relatório “itens abaixo do mínimo”.
# 167. “Sistema de notas”: cadastro aluno→lista de notas + média + status.
# 168. Sistema de notas: top 3 alunos por média.
# 169. Sistema de notas: aluno com maior evolução (última nota - primeira).
# 170. “Caixa”: registre transações (lista de dicts) e gere saldo final.
# 171. Caixa: gere relatório por tipo (entrada/saída) e total por categoria.
# 172. “Conversor de texto”: pipeline (normalizar → tokenizar → contar → top_k).
# 173. “Detector de duplicados”: ache repetições e posições em uma lista de strings.
# 174. “Validador”: lote de emails/senhas e relatório de quantos válidos/por regra.
# 175. “Jogo”: pedra-papel-tesoura contra CPU (pode fixar jogadas pra testar).
# 176. Jogo: histórico de rodadas e placar final.
# 177. “Quiz”: perguntas em lista de dicts, pontuação, e feedback final.
# 178. Quiz: embaralhar perguntas (se não quiser random, simule por rotação).
# 179. “Parser”: leia linhas “produto;preco;qtd” e monte dict estoque.
# 180. “Carrinho”: aplique cupons e descontos progressivos por regras.
# 181. “Ranking de palavras”: empate por alfabético, output formatado.
# 182. “Analisador de logs”: leia linhas “LEVEL - mensagem” e conte por level.
# 183. “Agrupador”: agrupe palavras por primeira letra e ordene cada grupo.
# 184. “Limpeza”: remova stopwords do texto e reconstrua frase.
# 185. “Resumo”: gere estatísticas do texto (n palavras, n únicas, top 10, etc).
# 186. Leia um arquivo `.txt` e conte linhas, palavras e caracteres.
# 187. Leia `.txt` e gere outro `.txt` só com linhas não vazias.
# 188. Leia `.txt` e salve top 20 palavras em outro arquivo.
# 189. Leia `.txt` e gere um “histograma” simples em texto (ex: `palavra: ####`).
# 190. Leia `.csv` simples (separado por `;`) e transforme em lista de dicts (sem pandas).
# 191. Escreva um arquivo de saída com dados formatados (relatório do estoque).
# 192. Implemente try/except no parser: linhas inválidas vão pra `erros.txt`.
# 193. Funções `carrega_dados(caminho)` e `salva_dados(caminho, dados)` (reuso real).
# 194. Refatore um mini-projeto pra não ter `input()` dentro das funções de regra.
# 195. Faça um “menu” que só chama funções puras + funções de I/O separadas.
# 196. Crie testes manuais: lista de casos e um loop que verifica resultados esperados.
# 197. Crie `pipeline(dados, funcoes)` que aplica uma lista de funções em sequência.
# 198. Crie `map_manual(func, lista)` e `filter_manual(pred, lista)` (sem usar map/filter).
# 199. Crie `reduce_manual(func, lista, inicial)` e use pra somar e pra achar maior.
# 200. Desafio final: relatório completo de texto (top palavras/letras, bigramas, stats) modular e com arquivos I/O.

# %% [markdown]
# ---
# ## Espaço de rascunho
#
# Use as células abaixo pra resolver. Sugestão:
# - 1 célula por exercício (ou por blocos de 5)
# - sempre coloque um comentário no topo: `# Ex 37`

# %%
# Exemplo de template
# Ex 1
# Leia um nome e imprima: Olá, <nome>!

# seu código aqui

# %%
# Ex 2
# Leia dois números e imprima soma, subtração, multiplicação e divisão (com 2 casas).

# seu código aqui
