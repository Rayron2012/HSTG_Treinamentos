# %% [markdown]
# # 📗 Parte 3: List Comprehension (Exercícios 21 a 40)
# Foco em filtros avançados, lógica matemática e manipulação de strings.

# %% [markdown]
# ### 21. Filtrar Palavras Longas
# **Objetivo:** Dada a lista `p = ['sol', 'planeta', 'lua', 'estrela']`, filtre apenas palavras com mais de 5 letras.

# %%
p = ['sol', 'planeta', 'lua', 'estrela']
# Sua resposta aqui:
longas = [n for n in p if len(n) > 5]

print(longas)
# Out:
# ['planeta', 'estrela']

# %% [markdown]
# ### 22. Substituição de Espaços
# **Objetivo:** Transformar a lista `frases = ['python é bom', 'amo programar']` substituindo espaços por hífens `-`.

# %%
frases = ['python é bom', 'amo programar']
# Sua resposta aqui:
com_hifen = [n for n in frases if "é" in n]

print(com_hifen)
# Out:
# ['python é bom']

# %% [markdown]
# ### 23. Múltiplos de 5 e 2
# **Objetivo:** Criar uma lista de 1 a 50 que contenha apenas números que sejam divisíveis por 2 **e** por 5 ao mesmo tempo.

# %%
# Sua resposta aqui:
multiplos =

# %% [markdown]
# ### 24. Verificar Maiúsculas
# **Objetivo:** Dada a lista `tags = ['Python', 'java', 'Ruby']`, retorne `True` se a palavra começar com maiúscula e `False` caso contrário.

# %%
tags = ['Python', 'java', 'Ruby']
# Sua resposta aqui:
checagem =

# %% [markdown]
# ### 25. Quadrado de Números Ímpares
# **Objetivo:** Calcule o quadrado apenas dos números ímpares de 1 a 10.

# %%
# Sua resposta aqui:
quadrado_impares =

# %% [markdown]
# ### 26. Criar Dicionário Simples
# **Objetivo:** Use List Comprehension para criar uma lista de strings no formato 'Chave: X', onde X é um número de 1 a 5.

# %%
# Sua resposta aqui:
chaves =

# %% [markdown]
# ### 27. Filtrar Nomes com Letra 'a'
# **Objetivo:** Dada a lista `nomes = ['Caio', 'Beto', 'Ana', 'Lia']`, filtre apenas os nomes que contenham a letra 'a' (minúscula).

# %%
nomes = ['Caio', 'Beto', 'Ana', 'Lia']
# Sua resposta aqui:
com_a =

# %% [markdown]
# ### 28. Transformar Booleano em Texto
# **Objetivo:** Dada a lista `status = [True, False, True]`, transforme em ['Ligado', 'Desligado', 'Ligado'].

# %%
status = [True, False, True]
# Sua resposta aqui:
texto_status =

# %% [markdown]
# ### 29. Adicionar Prefixo
# **Objetivo:** Adicione o prefixo 'cod_' a cada elemento da lista `ids = [101, 102, 103]`.

# %%
ids = [101, 102, 103]
# Sua resposta aqui:
cod_ids =

# %% [markdown]
# ### 30. Filtrar Números Divisíveis por 7
# **Objetivo:** Criar uma lista de 1 a 100 com números divisíveis por 7.

# %%
# Sua resposta aqui:
div_7 =

# %% [markdown]
# ### 31. Extrair Domínio de E-mail
# **Objetivo:** Dada a lista `emails = ['hiron@teste.com', 'ana@dev.com']`, extraia apenas o que vem depois do '@'.

# %%
emails = ['hiron@teste.com', 'ana@dev.com']
# Sua resposta aqui (Dica: use .split('@')[1]):
dominios =

# %% [markdown]
# ### 32. Inverter Sinais de Lista
# **Objetivo:** Transforme `[10, -20, 30]` em `[-10, 20, -30]`.

# %%
valores = [10, -20, 30]
# Sua resposta aqui:
invertidos =

# %% [markdown]
# ### 33. Filtro de Strings que são Números
# **Objetivo:** Dada a lista `dados = ['10', 'abc', '20', 'd']`, filtre apenas as strings que são numéricas (use `.isdigit()`).

# %%
dados = ['10', 'abc', '20', 'd']
# Sua resposta aqui:
so_numeros =

# %% [markdown]
# ### 34. Criar Lista de Coordenadas
# **Objetivo:** Crie uma lista de tuplas `(x, y)` onde x é de 0 a 2 e y é sempre 0.

# %%
# Sua resposta aqui:
coordenadas =

# %% [markdown]
# ### 35. Reduzir Valores pela Metade
# **Objetivo:** Divida todos os números da lista `precos = [100, 50, 10]` por 2.

# %%
precos = [100, 50, 10]
# Sua resposta aqui:
metade =

# %% [markdown]
# ### 36. Remover Espaços em Branco de Frases
# **Objetivo:** Remova todos os espaços de cada string na lista `itens = [' a b ', 'c d ']` usando `.replace(' ', '')`.

# %%
itens = [' a b ', 'c d ']
# Sua resposta aqui:
sem_espacos =

# %% [markdown]
# ### 37. Multiplicar se for Maior que 10
# **Objetivo:** Dada a lista `n = [5, 12, 8, 15]`, se o número for > 10, multiplique por 2, senão mantenha o original.

# %%
n = [5, 12, 8, 15]
# Sua resposta aqui:
processados =

# %% [markdown]
# ### 38. Contar Comprimento de Palavras
# **Objetivo:** Transforme `['oi', 'python']` em uma lista com a quantidade de letras de cada palavra.

# %%
palavras = ['oi', 'python']
# Sua resposta aqui:
tamanhos =

# %% [markdown]
# ### 39. Filtrar Valores Diferentes de Zero
# **Objetivo:** Filtre todos os valores que não sejam 0 da lista `v = [0, 1, 0, 2, 3, 0]`.

# %%
v = [0, 1, 0, 2, 3, 0]
# Sua resposta aqui:
sem_zero =

# %% [markdown]
# ### 40. Formatar Preços para String
# **Objetivo:** Transforme `[5.5, 10.0]` em `['R$ 5.5', 'R$ 10.0']`.

# %%
valores = [5.5, 10.0]
# Sua resposta aqui:
formatados =

# %% [markdown]
# ---

# %% [markdown]
# # 📘 Parte 4: Functions (Exercícios 41 a 60)
# Foco em lógica avançada, composição de funções e tratamento de dados.

# %% [markdown]
# ### 41. Cálculo de Desconto Progressivo
# **Objetivo:** Crie uma função `aplicar_desconto(valor)` que retorne o valor com 5% de desconto se for < 100, e 10% se for >= 100.

# %%
# Defina aqui:
def aplicar_desconto(valor):
    pass

# %% [markdown]
# ### 42. Verificador de Existência em Lista
# **Objetivo:** Crie uma função `esta_na_lista(item, lista)` que retorne `True` ou `False`.

# %%
# Defina aqui:
def esta_na_lista(item, lista):
    pass

# %% [markdown]
# ### 43. Função que Gera Lista de Pares
# **Objetivo:** Crie uma função `gerar_pares(n)` que retorne uma lista de números pares de 0 até n (inclusive).

# %%
# Defina aqui:
def gerar_pares(n):
    pass

# %% [markdown]
# ### 44. Somar Apenas Números (*args)
# **Objetivo:** Crie uma função `somar_numeros(*args)` que percorra os argumentos e some apenas os que forem do tipo `int` ou `float`.

# %%
# Defina aqui:
def somar_numeros(*args):
    pass

# %% [markdown]
# ### 45. Buscador de Chave de Configuração
# **Objetivo:** Crie uma função `get_config(chave, **kwargs)` que retorne o valor da chave. Se não existir, retorne 'Default'.

# %%
# Defina aqui:
def get_config(chave, **kwargs):
    pass

# %% [markdown]
# ### 46. Função de Potência Personalizada
# **Objetivo:** Crie uma função `potencia(base, exp=2)` que retorne a base elevada ao expoente.

# %%
# Defina aqui:
def potencia(base, exp=2):
    pass

# %% [markdown]
# ### 47. Formatar Nome Completo
# **Objetivo:** Crie uma função `nome_completo(nome, sobrenome)` que retorne os dois juntos com a primeira letra de cada um maiúscula.

# %%
# Defina aqui:
def nome_completo(nome, sobrenome):
    pass

# %% [markdown]
# ### 48. Calculadora de IMC
# **Objetivo:** Crie `calcular_imc(peso, altura)` que retorne `peso / (altura ** 2)`.

# %%
# Defina aqui:
def calcular_imc(peso, altura):
    pass

# %% [markdown]
# ### 49. Verificar Lista de Strings
# **Objetivo:** Crie uma função `tudo_string(lista)` que retorne `True` se todos os itens da lista forem strings.

# %%
# Defina aqui:
def tudo_string(lista):
    pass

# %% [markdown]
# ### 50. Função Maestro: Filtro e Soma
# **Objetivo:** Crie uma função `soma_filtrada(lista)` que chame uma função interna (ou use LC) para somar apenas os números positivos da lista.

# %%
# Defina aqui:
def soma_filtrada(lista):
    pass

# %% [markdown]
# ### 51. Converter Minutos em Horas
# **Objetivo:** Crie `converter_horas(minutos)` que retorne uma string no formato 'Xh Ymin'.

# %%
# Defina aqui:
def converter_horas(minutos):
    pass

# %% [markdown]
# ### 52. Gerador de Dicionário de Frequência
# **Objetivo:** Crie uma função `contar_itens(lista)` que retorne um dicionário com a contagem de cada item da lista.

# %%
# Defina aqui:
def contar_itens(lista):
    pass

# %% [markdown]
# ### 53. Filtrar e Inverter
# **Objetivo:** Crie uma função `filtra_inverte(lista)` que filtre apenas strings e as retorne invertidas.

# %%
# Defina aqui:
def filtra_inverte(lista):
    pass

# %% [markdown]
# ### 54. Multiplicador de Lista
# **Objetivo:** Crie uma função `multiplicar_lista(lista, fator)` que multiplique cada item da lista pelo fator.

# %%
# Defina aqui:
def multiplicar_lista(lista, fator):
    pass

# %% [markdown]
# ### 55. Verificar se é Inteiro
# **Objetivo:** Crie a função `eh_inteiro(valor)` que retorne `True` apenas se o tipo for `int`.

# %%
# Defina aqui:
def eh_inteiro(valor):
    pass

# %% [markdown]
# ### 56. Remover Espaços de Lista
# **Objetivo:** Crie a função `limpar_strings(lista)` que retorne a lista com todas as strings limpas de espaços nas extremidades.

# %%
# Defina aqui:
def limpar_strings(lista):
    pass

# %% [markdown]
# ### 57. Somar Dicionário de Preços
# **Objetivo:** Crie `total_precos(carrinho)` que receba um dicionário `{'item': preco}` e retorne a soma dos valores.

# %%
# Defina aqui:
def total_precos(carrinho):
    pass

# %% [markdown]
# ### 58. Filtrar Dicionário por Valor
# **Objetivo:** Crie a função `filtrar_caros(dicio, limite)` que retorne um novo dicionário apenas com itens que custam mais que o limite.

# %%
# Defina aqui:
def filtrar_caros(dicio, limite):
    pass

# %% [markdown]
# ### 59. Concatenar Strings (*args)
# **Objetivo:** Crie `unir_textos(*args)` que junte todos os textos passados com um espaço entre eles.

# %%
# Defina aqui:
def unir_textos(*args):
    pass

# %% [markdown]
# ### 60. Gerador de Resumo (Composição Final)
# **Objetivo:** Crie uma função que receba uma lista de números, use uma função interna para filtrar os pares, outra para elevar ao quadrado e retorne a soma final.

# %%
# Defina aqui:
def super_resumo(lista):
    pass
