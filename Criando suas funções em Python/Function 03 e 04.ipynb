# %% [markdown]
# # Argumentos/Parâmetros da Função
#
# ### Estrutura:

# %% [raw]
# def minha_funcao(parametro1, parametro2, parametro3):
#     return parametro1 + parametro2 + parametro3

# %% [markdown]
# - Exemplo: nosso famoso print

# %%
print("Teste1", "teste2", "teste3")
# Out:
# Teste1 teste2 teste3

# %% [markdown]
# - Só para mostrar o funcionamento, vamos criar uma função de soma

# %%
def soma (num1, num2, num3):
    return num1 + num2 + num3


soma = soma(10, 20, 30)

print(soma)
# Out:
# 60

# %% [markdown]
# - Vamos criar uma function com parâmetro
#
# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora de bebidas.
#
# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.
#
# Ex:<br>
# Vinho -> BEB12302<br>
# Cerveja -> BEB12043<br>
# Vodka -> BEB34501<br>
#
# Guaraná -> BSA11104<br>
# Coca -> BSA54301<br>
# Sprite -> BSA34012<br>
# Água -> BSA09871<br>
#
# Repare que bebidas não alcóolicas começam com BSA e bebidas alcoolicas começam com BEB.
#
# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de bebidas alcóolicas.

# %%
def tipo_bebida(bebida, cod_categoria):
    bebida = bebida.upper()
    if cod_categoria in bebida:
        return True
    else:
        return False


produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']


for produto in produtos:
    if tipo_bebida(produto, "BEB"):
        produto = produto.upper()
        print("Produto deve ser enviado ao setor de Bebidas: alcoolicas - {}".format(produto))
    elif tipo_bebida(produto, "BSA"):
        produto = produto.upper()
        print("Produto deve ser enviado ao setor de Bebidas: nao alcoolicas - {}".format(produto))
        # Keywords arguments é quando voce passa o nome do parametro na chamada da função, se fior feito dessa forma, a ordem dos parametros nao importa
        # Importante frezar que se passado um keyword argument, todos os parametros seguintes devem ser keyword arguments também
    elif tipo_bebida(produto, "CAR"):
        produto = produto.upper()
        print("Produto deve ser enviado ao setor de Carnes - {}".format(produto))
# Out:
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB46275
# Produto deve ser enviado ao setor de Bebidas: nao alcoolicas - BSA45510
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB21365
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB31623
# Produto deve ser enviado ao setor de Bebidas: nao alcoolicas - BSA62419
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB73344
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB80694
# Produto deve ser enviado ao setor de Bebidas: nao alcoolicas - BSA11769
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB19495
# Produto deve ser enviado ao setor de Bebidas: nao alcoolicas - BSA33484
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB97471
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB62362
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB85146
# Produto deve ser enviado ao setor de Bebidas: alcoolicas - BEB48898
# ...
