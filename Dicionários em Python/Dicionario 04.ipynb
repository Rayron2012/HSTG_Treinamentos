# %% [markdown]
# # For nos Dicionarios
#
# ### Estrutura:

# %% [raw]
# for chave in dicionario:
#     faça alguma coisa

# %%
vendas_tecnologia = {'iphone': 15000, 'samsung galaxy': 12000, 'tv samsung': 10000, 'ps5': 14300, 'tablet': 1720, 'ipad': 1000, 'tv philco': 2500, 'notebook hp': 1000, 'notebook dell': 17000, 'notebook asus': 2450}


#demonstrando o for
for chave in vendas_tecnologia:
    print("{} : {}".format(chave, vendas_tecnologia[chave]))
# Out:
# iphone : 15000
# samsung galaxy : 12000
# tv samsung : 10000
# ps5 : 14300
# tablet : 1720
# ipad : 1000
# tv philco : 2500
# notebook hp : 1000
# notebook dell : 17000
# notebook asus : 2450

# %% [markdown]
# - Qual o total de notebooks vendidos?

# %%
preco = []

for aparelho in vendas_tecnologia:
    if "notebook" in aparelho:
        preco.append(vendas_tecnologia[aparelho])
        soma = sum(preco)
print("A soma dos notebooks é: R${:,}".format(soma))
# Out:
# A soma dos notebooks é: R$20,450
